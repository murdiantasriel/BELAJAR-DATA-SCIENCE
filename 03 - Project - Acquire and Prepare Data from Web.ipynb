# %% [markdown]
# # Project - Acquire and Prepare Data from Web

# %% [markdown]
# ![Data Science Workflow](img/ds-workflow.png)

# %% [markdown]
# ## Goal of Project
# - This project will focus on Step 1 and 2 (**Acquire** and **Prepare**)
# - We will read raw data that needs Data Wrangling to prepare
# - The process we follow demonstrates how a Data Scientist works

# %% [markdown]
# ## Step 1: Acquire
# - Explore problem
# - Identify data
# - Import data

# %% [markdown]
# ### Step 1.a: Import libraries
# - Execute the cell below (SHIFT + ENTER)

# %%
import pandas as pd

# %% [markdown]
# ### Step 1.b: Retrieve/Read the data
# - There are two options to get data
# #### Option 1: Directly from wikipedia
# - Assign variable ```url = "https://en.wikipedia.org/wiki/Wikipedia:Fundraising_statistics"```
# - Retrieve the data ```tables = pd.read_html(url)```
# - Assign the first DataFrame to a variable
#     - HINT: ```tables``` is a list DataFrame containing all the data
#
# #### Option 2: From csv file (if option 1 fails)
# - Use ```pd.read_csv()``` to read the file `files/fundraising.csv`
# - NOTE: Remember to assign the result to a variable (e.g., ```data```)
# - Apply ```.head()``` on the data to see all is as expected

# %%
url='https://en.wikipedia.org/wiki/Wikipedia:Fundraising_statistics'

# %%
tables=pd.read_html(url)

# %%
tables[0].head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets
# 0  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 1  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 2  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 3  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 4  2016/17    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197

# %%
data=tables[0]

# %%
data
# Out:
#        Year Source        Revenue       Expenses    Asset rise   Total assets
# 0   2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 1   2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 2   2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 3   2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 4   2016/17    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 5   2015/16    PDF   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 6   2014/15    PDF   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 7   2013/14    PDF   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 8   2012/13    PDF   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 9   2011/12    PDF   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# 10  2010/11    PDF   $ 24,785,092   $ 17,889,794   $ 9,649,413   $ 24,192,144
# 11  2009/10    PDF   $ 17,979,312   $ 10,266,793   $ 6,310,964   $ 14,542,731
# 12  2008/09    PDF    $ 8,658,006    $ 5,617,236   $ 3,053,599    $ 8,231,767
# 13  2007/08    PDF    $ 5,032,981    $ 3,540,724   $ 3,519,886    $ 5,178,168
# 14  2006/07    PDF    $ 2,734,909    $ 2,077,843     $ 654,066    $ 1,658,282
# 15  2005/06    PDF    $ 1,508,039      $ 791,907     $ 736,132    $ 1,004,216
# 16  2004/05    PDF      $ 379,088      $ 177,670     $ 211,418      $ 268,084
# 17  2003/04    PDF       $ 80,129       $ 23,463      $ 56,666       $ 56,666

# %% [markdown]
# ## Step 2: Prepare
# - Explore data
# - Visualize ideas
# - Cleaning data

# %% [markdown]
# ### Step 2.a: Check the data types
# - This step tells you if some numeric column is not represented numeric.
# - Get the data types by ```.dtypes```

# %%
data.dtypes
# Out:
# Year            object
# Source          object
# Revenue         object
# Expenses        object
# Asset rise      object
# Total assets    object
# dtype: object

# %% [markdown]
# ### Step 2.b: Check for null (missing) values
# - Data often is missing entries - there can be many reasons for this
# - We need to deal with that (will do later in course)
# - Use ```.isna().any()```

# %%
data.isna().any()
# Out:
# Year            False
# Source          False
# Revenue         False
# Expenses        False
# Asset rise      False
# Total assets    False
# dtype: bool

# %% [markdown]
# ### Step 2.c: Delete Source Column
# - The Column Source adds no value for further investigations
# - You can delete it by
#     - ```del data['Source']```

# %%
data
# Out:
#        Year Source        Revenue       Expenses    Asset rise   Total assets
# 0   2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 1   2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 2   2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 3   2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 4   2016/17    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 5   2015/16    PDF   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 6   2014/15    PDF   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 7   2013/14    PDF   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 8   2012/13    PDF   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 9   2011/12    PDF   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# 10  2010/11    PDF   $ 24,785,092   $ 17,889,794   $ 9,649,413   $ 24,192,144
# 11  2009/10    PDF   $ 17,979,312   $ 10,266,793   $ 6,310,964   $ 14,542,731
# 12  2008/09    PDF    $ 8,658,006    $ 5,617,236   $ 3,053,599    $ 8,231,767
# 13  2007/08    PDF    $ 5,032,981    $ 3,540,724   $ 3,519,886    $ 5,178,168
# 14  2006/07    PDF    $ 2,734,909    $ 2,077,843     $ 654,066    $ 1,658,282
# 15  2005/06    PDF    $ 1,508,039      $ 791,907     $ 736,132    $ 1,004,216
# 16  2004/05    PDF      $ 379,088      $ 177,670     $ 211,418      $ 268,084
# 17  2003/04    PDF       $ 80,129       $ 23,463      $ 56,666       $ 56,666

# %% [markdown]
# ### Step 2.d: Convert Year column to numeric
# - All the strings in years are formatted: 'YYYY/YYYY'
# - To get the last year as string: ```data['Year'].str[-4:]```
# - To convert that to numeric use: ```pd.to_numeric(...)```
#     - HINT: You can assign the column directly

# %%
data['Year']=data['Year'].str[:-3]

# %%
data
# Out:
#     Year Source        Revenue       Expenses    Asset rise   Total assets
# 0   2020    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 1   2019    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 2   2018    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 3   2017    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 4   2016    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 5   2015    PDF   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 6   2014    PDF   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 7   2013    PDF   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 8   2012    PDF   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 9   2011    PDF   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# 10  2010    PDF   $ 24,785,092   $ 17,889,794   $ 9,649,413   $ 24,192,144
# 11  2009    PDF   $ 17,979,312   $ 10,266,793   $ 6,310,964   $ 14,542,731
# 12  2008    PDF    $ 8,658,006    $ 5,617,236   $ 3,053,599    $ 8,231,767
# 13  2007    PDF    $ 5,032,981    $ 3,540,724   $ 3,519,886    $ 5,178,168
# 14  2006    PDF    $ 2,734,909    $ 2,077,843     $ 654,066    $ 1,658,282
# 15  2005    PDF    $ 1,508,039      $ 791,907     $ 736,132    $ 1,004,216
# 16  2004    PDF      $ 379,088      $ 177,670     $ 211,418      $ 268,084
# 17  2003    PDF       $ 80,129       $ 23,463      $ 56,666       $ 56,666

# %% [markdown]
# ### Step 2.e: Set Year to index
# - To change a column to be the index use: ```data.set_index('Year', inplace=True)```
# - Also sort the index in correct order: ```data.sort_index(inplace=True)```

# %%
data.set_index('Year',inplace=True)

# %%
data
# Out:
#      Source        Revenue       Expenses    Asset rise   Total assets
# Year
# 2020    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2019    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 2018    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 2017    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 2016    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 2015    PDF   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 2014    PDF   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 2013    PDF   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 2012    PDF   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 2011    PDF   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# 2010    PDF   $ 24,785,092   $ 17,889,794   $ 9,649,413   $ 24,192,144
# 2009    PDF   $ 17,979,312   $ 10,266,793   $ 6,310,964   $ 14,542,731
# 2008    PDF    $ 8,658,006    $ 5,617,236   $ 3,053,599    $ 8,231,767
# 2007    PDF    $ 5,032,981    $ 3,540,724   $ 3,519,886    $ 5,178,168
# 2006    PDF    $ 2,734,909    $ 2,077,843     $ 654,066    $ 1,658,282
# 2005    PDF    $ 1,508,039      $ 791,907     $ 736,132    $ 1,004,216
# 2004    PDF      $ 379,088      $ 177,670     $ 211,418      $ 268,084
# 2003    PDF       $ 80,129       $ 23,463      $ 56,666       $ 56,666

# %%
data.sort_index(inplace=True)

# %%
data
# Out:
#      Source        Revenue       Expenses    Asset rise   Total assets
# Year
# 2003    PDF       $ 80,129       $ 23,463      $ 56,666       $ 56,666
# 2004    PDF      $ 379,088      $ 177,670     $ 211,418      $ 268,084
# 2005    PDF    $ 1,508,039      $ 791,907     $ 736,132    $ 1,004,216
# 2006    PDF    $ 2,734,909    $ 2,077,843     $ 654,066    $ 1,658,282
# 2007    PDF    $ 5,032,981    $ 3,540,724   $ 3,519,886    $ 5,178,168
# 2008    PDF    $ 8,658,006    $ 5,617,236   $ 3,053,599    $ 8,231,767
# 2009    PDF   $ 17,979,312   $ 10,266,793   $ 6,310,964   $ 14,542,731
# 2010    PDF   $ 24,785,092   $ 17,889,794   $ 9,649,413   $ 24,192,144
# 2011    PDF   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# 2012    PDF   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 2013    PDF   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 2014    PDF   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 2015    PDF   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 2016    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 2017    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 2018    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 2019    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 2020    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536

# %% [markdown]
# ### Step 2.f: Convert the remaining columns to numeric
# - Remember the steps from the lesson
#     - ```.str[2:]``` to remove the first two characters ('\$ ')
#     - ```.str.replace(',', '')``` to remove commas
#     - ```pd.to_numeric(...)``` converts string (containing well-formed number) to the numeric value
# - Try to do it directly column by column

# %%
data.dtypes
# Out:
# Source          object
# Revenue         object
# Expenses        object
# Asset rise      object
# Total assets    object
# dtype: object

# %%
del data['Source']

# %%
data
# Out:
#             Revenue       Expenses    Asset rise   Total assets
# Year
# 2003       $ 80,129       $ 23,463      $ 56,666       $ 56,666
# 2004      $ 379,088      $ 177,670     $ 211,418      $ 268,084
# 2005    $ 1,508,039      $ 791,907     $ 736,132    $ 1,004,216
# 2006    $ 2,734,909    $ 2,077,843     $ 654,066    $ 1,658,282
# 2007    $ 5,032,981    $ 3,540,724   $ 3,519,886    $ 5,178,168
# 2008    $ 8,658,006    $ 5,617,236   $ 3,053,599    $ 8,231,767
# 2009   $ 17,979,312   $ 10,266,793   $ 6,310,964   $ 14,542,731
# 2010   $ 24,785,092   $ 17,889,794   $ 9,649,413   $ 24,192,144
# 2011   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# 2012   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 2013   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 2014   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 2015   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 2016   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 2017  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 2018  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 2019  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 2020  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536

# %%
data.dtypes
# Out:
# Revenue         object
# Expenses        object
# Asset rise      object
# Total assets    object
# dtype: object

# %%
data['Revenue']=data['Revenue'].str[2:]

# %%
data
# Out:
#           Revenue       Expenses    Asset rise   Total assets
# Year
# 2003       80,129       $ 23,463      $ 56,666       $ 56,666
# 2004      379,088      $ 177,670     $ 211,418      $ 268,084
# 2005    1,508,039      $ 791,907     $ 736,132    $ 1,004,216
# 2006    2,734,909    $ 2,077,843     $ 654,066    $ 1,658,282
# 2007    5,032,981    $ 3,540,724   $ 3,519,886    $ 5,178,168
# 2008    8,658,006    $ 5,617,236   $ 3,053,599    $ 8,231,767
# 2009   17,979,312   $ 10,266,793   $ 6,310,964   $ 14,542,731
# 2010   24,785,092   $ 17,889,794   $ 9,649,413   $ 24,192,144
# 2011   38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# 2012   48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 2013   52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 2014   75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 2015   81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 2016   91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 2017  104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 2018  120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 2019  129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 2020  162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536

# %%
data['Revenue']=data['Revenue'].str.replace(',','')

# %%
data['Revenue']=pd.to_numeric(data['Revenue'])

# %%
data
# Out:
#         Revenue       Expenses    Asset rise   Total assets
# Year
# 2003      80129       $ 23,463      $ 56,666       $ 56,666
# 2004     379088      $ 177,670     $ 211,418      $ 268,084
# 2005    1508039      $ 791,907     $ 736,132    $ 1,004,216
# 2006    2734909    $ 2,077,843     $ 654,066    $ 1,658,282
# 2007    5032981    $ 3,540,724   $ 3,519,886    $ 5,178,168
# 2008    8658006    $ 5,617,236   $ 3,053,599    $ 8,231,767
# 2009   17979312   $ 10,266,793   $ 6,310,964   $ 14,542,731
# 2010   24785092   $ 17,889,794   $ 9,649,413   $ 24,192,144
# 2011   38479665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# 2012   48635408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 2013   52465287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 2014   75797223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 2015   81862724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 2016   91242418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 2017  104505783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 2018  120067266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 2019  129234327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 2020  162886686  $ 111,839,819  $ 50,861,811  $ 231,177,536

# %%
data.isna().any()
# Out:
# Revenue         False
# Expenses        False
# Asset rise      False
# Total assets    False
# dtype: bool

# %%
data['Expenses']=data['Expenses'].str[2:]
data['Asset rise']=data['Asset rise'].str[2:]
data['Total assets']=data['Total assets'].str[2:]

# %%
data
# Out:
#         Revenue     Expenses  Asset rise Total assets
# Year
# 2003      80129       23,463      56,666       56,666
# 2004     379088      177,670     211,418      268,084
# 2005    1508039      791,907     736,132    1,004,216
# 2006    2734909    2,077,843     654,066    1,658,282
# 2007    5032981    3,540,724   3,519,886    5,178,168
# 2008    8658006    5,617,236   3,053,599    8,231,767
# 2009   17979312   10,266,793   6,310,964   14,542,731
# 2010   24785092   17,889,794   9,649,413   24,192,144
# 2011   38479665   29,260,652  10,736,914   34,929,058
# 2012   48635408   35,704,796  10,260,066   45,189,124
# 2013   52465287   45,900,745   8,285,897   53,475,021
# 2014   75797223   52,596,782  24,345,277   77,820,298
# 2015   81862724   65,947,465  13,962,497   91,782,795
# 2016   91242418   69,136,758  21,547,402  113,330,197
# 2017  104505783   81,442,265  21,619,373  134,949,570
# 2018  120067266   91,414,010  30,691,855  165,641,425
# 2019  129234327  112,489,397  14,674,300  180,315,725
# 2020  162886686  111,839,819  50,861,811  231,177,536

# %%
data['Expenses']=data['Expenses'].str.replace(',','')
data['Asset rise']=data['Asset rise'].str.replace(',','')
data['Total assets']=data['Total assets'].str.replace(',','')

# %%
data['Expenses']=pd.to_numeric(data['Expenses'])
data['Asset rise']=pd.to_numeric(data['Asset rise'])
data['Total assets']=pd.to_numeric(data['Total assets'])

# %% [markdown]
# ### Step 2.g: Visualize data to investigate quality
# - Make a simple plot of **Revenue**, **Expenses** and **Total assets**
# - This will help you spot any outliers

# %%
data[['Expenses','Asset rise','Total assets']].plot.line()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# ### Step 2.h: Visualize data to investigate quality
# - Make a simple plot of **Asset rise**
# - This will help you spot any outliers

# %%
data.plot.scatter(x='Expenses',y='Asset rise',alpha=.5,c='r')
# Out:
# <AxesSubplot:xlabel='Expenses', ylabel='Asset rise'>
