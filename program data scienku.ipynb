# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('files/titanic.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Lname        156 non-null    object
#  4   Name         156 non-null    object
#  5   Sex          156 non-null    object
#  6   Age          126 non-null    float64
#  7   SibSp        156 non-null    int64
#  8   Parch        156 non-null    int64
#  9   Ticket       156 non-null    object
#  10  Fare         156 non-null    float64
#  11  Cabin        31 non-null     object
#  12  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 16.0+ KB

# %%
data
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Lname           object
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
ages=data['Age']

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                            Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# ...

# %%
age_sex=data[['Age','Sex']]

# %%
age_sex.groupby('Sex').count()
# Out:
#         Age
# Sex
# female   47
# male     79

# %%
age=data['Age']

# %%
age[data['Age']>22]
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 6      54.0
#        ...
# 149    42.0
# 150    51.0
# 152    55.5
# 153    40.5
# 155    51.0
# Name: Age, Length: 75, dtype: float64

# %%
age[data['Age']>22].count()
# Out:
# 75

# %%
age_20=age[data['Age']>20]
age_30=age[data['Age']<20]

# %%
data.groupby(age_20).sum()
# Out:
#       PassengerId  Survived  Pclass    Age  SibSp  Parch      Fare
# Age
# 21.0          667         2      19  168.0      2      1  266.2125
# 22.0          550         2      16  132.0      2      0  105.8792
# 23.0          323         2       4   69.0      3      3  341.4041
# 24.0          620         2      11  120.0      1      1  357.7625
# 25.0          211         0       5   50.0      0      0   20.6500
# 26.0          241         1      12  104.0      4      2   51.6167
# 27.0          198         2       8   81.0      1      2   39.9291
# 28.0          350         1       9  140.0      1      0  180.5624
# 28.5           58         0       3   28.5      0      0    7.2292
# 29.0          546         4      14  174.0      3      0  101.0500
# 30.0           80         1       3   30.0      0      0   12.4750
# 31.0           19         0       3   31.0      1      0   18.0000
# 32.0          146         1       5   64.0      0      0   66.9958
# ...

# %%
above_35=data[data['Age']>35]

# %%
above_35
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 1              2         1       1       Cumings
# 6              7         0       1      McCarthy
# 11            12         1       1       Bonnell
# 13            14         0       3     Andersson
# 15            16         1       2       Hewlett
# 25            26         1       3       Asplund
# 30            31         0       1     Uruchurtu
# 33            34         0       2       Wheadon
# 35            36         0       1     Holverson
# 40            41         0       3         Ahlin
# 52            53         1       1        Harper
# 54            55         0       1         Ostby
# 61            62         1       1         Icard
# 62            63         0       1        Harris
# 92            93         0       1       Chaffee
# 94            95         0       3         Coxon
# 96            97         0       1   Goldschmidt
# 104          105         0       3    Gustafsson
# ...

# %%
above_35.sum()
# Out:
# C:\Users\MSI\AppData\Local\Temp/ipykernel_5772/572216871.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   above_35.sum()
# PassengerId                                                 2618
# Survived                                                       6
# Pclass                                                        58
# Lname          CumingsMcCarthyBonnellAnderssonHewlettAsplundU...
# Name            Mrs. John Bradley (Florence Briggs Thayer) Mr...
# Sex            femalemalefemalemalefemalefemalemalemalemalefe...
# Age                                                       1495.0
# SibSp                                                         12
# Parch                                                         17
# Ticket         PC 1759917463113783347082248706347077PC 17601C...
# ...

# %%
age_sex
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 151  22.0  female
# 152  55.5    male
# 153  40.5    male
# 154   NaN    male
# 155  51.0    male
#
# [156 rows x 2 columns]

# %%
age_sex.groupby('Sex').count()
# Out:
#         Age
# Sex
# female   47
# male     79

# %%
age_sex.shape
# Out:
# (156, 2)

# %%
age_sex.tail(56)
# Out:
#       Age     Sex
# 100  28.0  female
# 101   NaN    male
# 102  21.0    male
# 103  33.0    male
# 104  37.0    male
# 105  28.0    male
# 106  21.0  female
# 107   NaN    male
# 108  38.0    male
# 109   NaN  female
# 110  47.0    male
# 111  14.5  female
# 112  22.0    male
# 113  20.0  female
# 114  17.0  female
# 115  21.0    male
# 116  70.5    male
# 117  29.0    male
# 118  24.0    male
# 119   2.0  female
# 120  21.0    male
# 121   NaN    male
# 122  32.5    male
# 123  32.5  female
# 124  54.0    male
# 125  12.0    male
# 126   NaN    male
# 127  24.0    male
# 128   NaN  female
# 129  45.0    male
# 130  33.0    male
# 131  20.0    male
# 132  47.0  female
# 133  29.0  female
# 134  25.0    male
# 135  23.0    male
# 136  19.0  female
# 137  37.0    male
# 138  16.0    male
# 139  24.0    male
# 140   NaN  female
# 141  22.0  female
# 142  24.0  female
# 143  19.0    male
# 144  18.0    male
# 145  19.0    male
# 146  27.0    male
# 147   9.0  female
# 148  36.5    male
# ...

# %%
data[data["Pclass"].isin([2,3])]
# Out:
#      PassengerId  Survived  Pclass         Lname                         Name  \
# 0              1         0       3        Braund              Mr. Owen Harris
# 2              3         1       3     Heikkinen                  Miss. Laina
# 4              5         0       3         Allen            Mr. William Henry
# 5              6         0       3         Moran                    Mr. James
# 7              8         0       3       Palsson        Master. Gosta Leonard
# ..           ...       ...     ...           ...                          ...
# 149          150         0       2         Byles   Rev. Thomas Roussel Davids
# 150          151         0       2       Bateman            Rev. Robert James
# 152          153         0       3           Meo                  Mr. Alfonzo
# 153          154         0       3  van Billiard            Mr. Austin Blyler
# 154          155         0       3         Olsen               Mr. Ole Martin
#
# ...

# %%
data[data['Pclass'].isin([2])].count()
# Out:
# PassengerId    30
# Survived       30
# Pclass         30
# Lname          30
# Name           30
# Sex            30
# Age            29
# SibSp          30
# Parch          30
# Ticket         30
# Fare           30
# Cabin           4
# Embarked       30
# dtype: int64

# %%
data.groupby(data['Pclass']).count()
# Out:
#         PassengerId  Survived  Lname  Name  Sex  Age  SibSp  Parch  Ticket  \
# Pclass
# 1                30        30     30    30   30   27     30     30      30
# 2                30        30     30    30   30   29     30     30      30
# 3                96        96     96    96   96   70     96     96      96
#
#         Fare  Cabin  Embarked
# Pclass
# 1         30     24        29
# 2         30      4        30
# 3         96      3        96

# %%
data.groupby(data['Pclass'].isin([1])).count()
# Out:
#         PassengerId  Survived  Pclass  Lname  Name  Sex  Age  SibSp  Parch  \
# Pclass
# False           126       126     126    126   126  126   99    126    126
# True             30        30      30     30    30   30   27     30     30
#
#         Ticket  Fare  Cabin  Embarked
# Pclass
# False      126   126      7       126
# True        30    30     24        29

# %%
avg=data["Age"].mean()

# %%
avg
# Out:
# 28.141507936507935

# %%
data['Survived'].sum()
# Out:
# 54

# %%
data['Survived'].groupby(data['Sex']).sum()
# Out:
# Sex
# female    40
# male      14
# Name: Survived, dtype: int64

# %%
data['Survived'].groupby(data['Sex']).sum()
# Out:
# Sex
# female    40
# male      14
# Name: Survived, dtype: int64

# %%
data2=pd.read_csv('files/titanic.csv',index_col=0,parse_dates=True)

# %%
data2
# Out:
#              Survived  Pclass         Lname  \
# PassengerId
# 1                   0       3        Braund
# 2                   1       1       Cumings
# 3                   1       3     Heikkinen
# 4                   1       1      Futrelle
# 5                   0       3         Allen
# ...               ...     ...           ...
# 152                 1       1         Pears
# 153                 0       3           Meo
# 154                 0       3  van Billiard
# 155                 0       3         Olsen
# 156                 0       1      Williams
#
#                                                     Name     Sex   Age  SibSp  \
# PassengerId
# 1                                        Mr. Owen Harris    male  22.0      1
# 2             Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 3                                            Miss. Laina  female  26.0      0
# 4                     Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
air_quality=pd.read_csv('files/air_quality.csv')

# %%
air_quality[['Eastern','Sha Tin']].scatter(figsize=(18,6))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5772/933609092.py in <module>
# ----> 1 air_quality[['Eastern','Sha Tin']].scatter(figsize=(18,6))
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'scatter'

# %%
plt.scatter(x='Eastern',y='Sha Tin')
# Out:
#   File "C:\Users\MSI\AppData\Local\Temp/ipykernel_5772/1670594955.py", line 1
#     plt.scatter(Eastern,Sha Tin)
#                             ^
# SyntaxError: invalid syntax

# %%
x=air_quality['Eastern']
y=air_quality['Sha Tin']

# %%
plt.scatter(x, y)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
