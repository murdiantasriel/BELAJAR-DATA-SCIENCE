# %% [markdown]
# # Project - Identify Data

# %% [markdown]
# ![Data Science Workflow](img/ds-workflow.png)

# %% [markdown]
# ## Goal of Project
# - World population growth rate
# - Is the growth rate stable? Increasing or Declining?

# %% [markdown]
# ## Step 1: Acquire
# - Explore problem
# - Identify data
# - Import data

# %% [markdown]
# ### Step 1.a: Explore and understand problem
# - What data do we need to answer the problem?

# %% [markdown]
# ### Step 1.b: Indentify data with world population
# - There are multiple sources
# - World bank: https://data.worldbank.org/indicator/SP.POP.TOTL
# - Wiki: https://en.wikipedia.org/wiki/World_population
# - ...and probably more

# %% [markdown]
# ### Step 1.c: Download and import the data
# - We will download it from World Bank

# %% [markdown]
# ### Step 1.d: Import libraries
# - Execute the cell below (SHIFT + ENTER)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 1.e: Read the data
# - Use ```pd.read_csv()``` to read the file `files/API_SP/API_SP.POP.TOTL_DS2_en_csv_v2_3158886.csv`
# - NOTE: Remember to assign the result to a variable (e.g., ```data```)
# - HELP: You might need to `skiprows=4`
# - Apply ```.head()``` on the data to see all is as expected

# %%
data=pd.read_csv("files/API_SP/API_SP.POP.TOTL_DS2_en_csv_v2_3158886.csv",skiprows=4)
data.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965  ...         2012         2013         2014         2015  \
# 0      57357.0  ...     102565.0     103165.0     103776.0     104339.0
# 1  148769974.0  ...  547482863.0  562601578.0  578075373.0  593871847.0
# 2    9956318.0  ...   31161378.0   32269592.0   33370804.0   34413603.0
# 3  107289875.0  ...  370243017.0  380437896.0  390882979.0  401586651.0
# 4    5770573.0  ...   25107925.0   26015786.0   26941773.0   27884380.0
#
#           2016         2017         2018         2019         2020  \
# 0     104865.0     105361.0     105846.0     106310.0     106766.0
# 1  609978946.0  626392880.0  643090131.0  660046272.0  677243299.0
# 2   35383028.0   36296111.0   37171922.0   38041757.0   38928341.0
# 3  412551299.0  423769930.0  435229381.0  446911598.0  458803476.0
# 4   28842482.0   29816769.0   30809787.0   31825299.0   32866268.0
#
#    Unnamed: 65
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 66 columns]

# %% [markdown]
# ### Step 1.f: Get world data
# - We are only insterested in data for the world.
# - The data can be identified by `Country Name` (World) or `Country Code` (WLD).
# - This can be done as follows:
# ```Python
# data[data['Country Name'] == 'World']
# ```
# - NOTE: Remember to keep data

# %%
data.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2017              float64
# 2018              float64
# 2019              float64
# 2020              float64
# Unnamed: 65       float64
# Length: 66, dtype: object

# %%
selection = data.select_dtypes('float64')
selection
# Out:
#             1960         1961         1962         1963         1964  \
# 0        54208.0      55434.0      56234.0      56699.0      57029.0
# 1    130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2      8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3     96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4      5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
# ..           ...          ...          ...          ...          ...
# 261     947000.0     966000.0     994000.0    1022000.0    1050000.0
# 262    5315351.0    5393034.0    5473671.0    5556767.0    5641598.0
# 263   17099836.0   17524533.0   17965733.0   18423157.0   18896303.0
# 264    3070780.0    3164330.0    3260645.0    3360099.0    3463211.0
# 265    3776679.0    3905038.0    4039209.0    4178726.0    4322854.0
#
#             1965         1966         1967         1968         1969  ...  \
# 0        57357.0      57702.0      58044.0      58377.0      58734.0  ...
# 1    148769974.0  152752671.0  156876454.0  161156430.0  165611760.0  ...
# 2      9956318.0   10174840.0   10399936.0   10637064.0   10893772.0  ...
# 3    107289875.0  109701811.0  112195950.0  114781116.0  117468741.0  ...
# 4      5770573.0    5781305.0    5774440.0    5771973.0    5803677.0  ...
# ..           ...          ...          ...          ...          ...  ...
# 261    1078000.0    1106000.0    1135000.0    1163000.0    1191000.0  ...
# 262    5727745.0    5816241.0    5907873.0    6001858.0    6097042.0  ...
# 263   19384838.0   19888259.0   20406863.0   20942147.0   21496075.0  ...
# 264    3570466.0    3681953.0    3797877.0    3918872.0    4045740.0  ...
# 265    4471178.0    4623340.0    4779825.0    4941901.0    5111326.0  ...
#
#             2012         2013         2014         2015         2016  \
# 0       102565.0     103165.0     103776.0     104339.0     104865.0
# 1    547482863.0  562601578.0  578075373.0  593871847.0  609978946.0
# 2     31161378.0   32269592.0   33370804.0   34413603.0   35383028.0
# 3    370243017.0  380437896.0  390882979.0  401586651.0  412551299.0
# 4     25107925.0   26015786.0   26941773.0   27884380.0   28842482.0
# ..           ...          ...          ...          ...          ...
# 261    1807106.0    1818117.0    1812771.0    1788196.0    1777557.0
# 262   24473176.0   25147112.0   25823488.0   26497881.0   27168210.0
# 263   52832659.0   53687125.0   54544184.0   55386369.0   56207649.0
# 264   14465148.0   14926551.0   15399793.0   15879370.0   16363449.0
# 265   13115149.0   13350378.0   13586710.0   13814642.0   14030338.0
#
#             2017         2018         2019         2020  Unnamed: 65
# 0       105361.0     105846.0     106310.0     106766.0          NaN
# 1    626392880.0  643090131.0  660046272.0  677243299.0          NaN
# 2     36296111.0   37171922.0   38041757.0   38928341.0          NaN
# 3    423769930.0  435229381.0  446911598.0  458803476.0          NaN
# 4     29816769.0   30809787.0   31825299.0   32866268.0          NaN
# ..           ...          ...          ...          ...          ...
# 261    1791003.0    1797085.0    1788878.0    1775378.0          NaN
# 262   27834811.0   28498683.0   29161922.0   29825968.0          NaN
# 263   57009751.0   57792520.0   58558267.0   59308690.0          NaN
# 264   16853608.0   17351714.0   17861034.0   18383956.0          NaN
# 265   14236599.0   14438812.0   14645473.0   14862927.0          NaN
#
# [266 rows x 62 columns]

# %%
data.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965  ...         2012         2013         2014         2015  \
# 0      57357.0  ...     102565.0     103165.0     103776.0     104339.0
# 1  148769974.0  ...  547482863.0  562601578.0  578075373.0  593871847.0
# 2    9956318.0  ...   31161378.0   32269592.0   33370804.0   34413603.0
# 3  107289875.0  ...  370243017.0  380437896.0  390882979.0  401586651.0
# 4    5770573.0  ...   25107925.0   26015786.0   26941773.0   27884380.0
#
#           2016         2017         2018         2019         2020  \
# 0     104865.0     105361.0     105846.0     106310.0     106766.0
# 1  609978946.0  626392880.0  643090131.0  660046272.0  677243299.0
# 2   35383028.0   36296111.0   37171922.0   38041757.0   38928341.0
# 3  412551299.0  423769930.0  435229381.0  446911598.0  458803476.0
# 4   28842482.0   29816769.0   30809787.0   31825299.0   32866268.0
#
#    Unnamed: 65
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 66 columns]

# %%
dataset=data['1960']

# %%
dataset.plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Step 2: Prepare
# - Explore data
# - Visualize ideas
# - Cleaning data

# %% [markdown]
# ### Step 2.a: Check the data types
# - This step tells you if some numeric column is not represented numeric.
# - Get the data types by ```.dtypes```

# %%
data.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2017              float64
# 2018              float64
# 2019              float64
# 2020              float64
# Unnamed: 65       float64
# Length: 66, dtype: object

# %% [markdown]
# ### Step 2.b: Keep only needed columns
# - We are only interested in the year columns.
# - You can drop the other columns by: ```.drop(list_of_columns_to_delete, axis='columns')```
# - Notice there is a `unnamed` column.
#     - Remove it with `dataset.dropna(how='all', axis='columns')`

# %%
data.isna().any()
# Out:
# Country Name      False
# Country Code      False
# Indicator Name    False
# Indicator Code    False
# 1960               True
#                   ...
# 2017               True
# 2018               True
# 2019               True
# 2020               True
# Unnamed: 65        True
# Length: 66, dtype: bool

# %%
dataset=data.dropna(how='all', axis='columns')

# %%
data
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54208.0      55434.0      56234.0      56699.0
# 1      SP.POP.TOTL  130836765.0  134159786.0  137614644.0  141202036.0
# 2      SP.POP.TOTL    8996967.0    9169406.0    9351442.0    9543200.0
# 3      SP.POP.TOTL   96396419.0   98407221.0  100506960.0  102691339.0
# 4      SP.POP.TOTL    5454938.0    5531451.0    5608499.0    5679409.0
# ..             ...          ...          ...          ...          ...
# 261    SP.POP.TOTL     947000.0     966000.0     994000.0    1022000.0
# 262    SP.POP.TOTL    5315351.0    5393034.0    5473671.0    5556767.0
# 263    SP.POP.TOTL   17099836.0   17524533.0   17965733.0   18423157.0
# 264    SP.POP.TOTL    3070780.0    3164330.0    3260645.0    3360099.0
# 265    SP.POP.TOTL    3776679.0    3905038.0    4039209.0    4178726.0
#
#             1964         1965  ...         2012         2013         2014  \
# 0        57029.0      57357.0  ...     102565.0     103165.0     103776.0
# 1    144920186.0  148769974.0  ...  547482863.0  562601578.0  578075373.0
# 2      9744772.0    9956318.0  ...   31161378.0   32269592.0   33370804.0
# 3    104953470.0  107289875.0  ...  370243017.0  380437896.0  390882979.0
# 4      5734995.0    5770573.0  ...   25107925.0   26015786.0   26941773.0
# ..           ...          ...  ...          ...          ...          ...
# 261    1050000.0    1078000.0  ...    1807106.0    1818117.0    1812771.0
# 262    5641598.0    5727745.0  ...   24473176.0   25147112.0   25823488.0
# 263   18896303.0   19384838.0  ...   52832659.0   53687125.0   54544184.0
# 264    3463211.0    3570466.0  ...   14465148.0   14926551.0   15399793.0
# 265    4322854.0    4471178.0  ...   13115149.0   13350378.0   13586710.0
#
#             2015         2016         2017         2018         2019  \
# 0       104339.0     104865.0     105361.0     105846.0     106310.0
# 1    593871847.0  609978946.0  626392880.0  643090131.0  660046272.0
# 2     34413603.0   35383028.0   36296111.0   37171922.0   38041757.0
# 3    401586651.0  412551299.0  423769930.0  435229381.0  446911598.0
# 4     27884380.0   28842482.0   29816769.0   30809787.0   31825299.0
# ..           ...          ...          ...          ...          ...
# 261    1788196.0    1777557.0    1791003.0    1797085.0    1788878.0
# 262   26497881.0   27168210.0   27834811.0   28498683.0   29161922.0
# 263   55386369.0   56207649.0   57009751.0   57792520.0   58558267.0
# 264   15879370.0   16363449.0   16853608.0   17351714.0   17861034.0
# 265   13814642.0   14030338.0   14236599.0   14438812.0   14645473.0
#
#             2020  Unnamed: 65
# 0       106766.0          NaN
# 1    677243299.0          NaN
# 2     38928341.0          NaN
# 3    458803476.0          NaN
# 4     32866268.0          NaN
# ..           ...          ...
# 261    1775378.0          NaN
# 262   29825968.0          NaN
# 263   59308690.0          NaN
# 264   18383956.0          NaN
# 265   14862927.0          NaN
#
# [266 rows x 66 columns]

# %% [markdown]
# ### Step 2.c: Transpose data
# - It makes sense to have years in the rows
# - This can be done with `.transpose()`

# %%
data1=data['1990']

# %%
data1.transpose()
# Out:
# 0          62152.0
# 1      304648010.0
# 2       12412311.0
# 3      204803865.0
# 4       11848385.0
#           ...
# 261      1862000.0
# 262     11709987.0
# 263     36800507.0
# 264      8036849.0
# 265     10432409.0
# Name: 1990, Length: 266, dtype: float64

# %%
data1.head
# Out:
# <bound method NDFrame.head of 0          62152.0
# 1      304648010.0
# 2       12412311.0
# 3      204803865.0
# 4       11848385.0
#           ...
# 261      1862000.0
# 262     11709987.0
# 263     36800507.0
# 264      8036849.0
# 265     10432409.0
# Name: 1990, Length: 266, dtype: float64>

# %% [markdown]
# ### Step 2.d: Rename column
# - The name 259 can be renamed as follows
# - This can be done as follows
# ```.rename(columns={259:'World Population'})```

# %%
dataset=dataset.rename(columns={'1960':'World Population'})

# %%
dataset
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code  World Population         1961         1962         1963  \
# 0      SP.POP.TOTL           54208.0      55434.0      56234.0      56699.0
# 1      SP.POP.TOTL       130836765.0  134159786.0  137614644.0  141202036.0
# 2      SP.POP.TOTL         8996967.0    9169406.0    9351442.0    9543200.0
# 3      SP.POP.TOTL        96396419.0   98407221.0  100506960.0  102691339.0
# 4      SP.POP.TOTL         5454938.0    5531451.0    5608499.0    5679409.0
# ..             ...               ...          ...          ...          ...
# 261    SP.POP.TOTL          947000.0     966000.0     994000.0    1022000.0
# 262    SP.POP.TOTL         5315351.0    5393034.0    5473671.0    5556767.0
# 263    SP.POP.TOTL        17099836.0   17524533.0   17965733.0   18423157.0
# 264    SP.POP.TOTL         3070780.0    3164330.0    3260645.0    3360099.0
# 265    SP.POP.TOTL         3776679.0    3905038.0    4039209.0    4178726.0
#
#             1964         1965  ...         2011         2012         2013  \
# 0        57029.0      57357.0  ...     102050.0     102565.0     103165.0
# 1    144920186.0  148769974.0  ...  532760424.0  547482863.0  562601578.0
# 2      9744772.0    9956318.0  ...   30117411.0   31161378.0   32269592.0
# 3    104953470.0  107289875.0  ...  360285439.0  370243017.0  380437896.0
# 4      5734995.0    5770573.0  ...   24220660.0   25107925.0   26015786.0
# ..           ...          ...  ...          ...          ...          ...
# 261    1050000.0    1078000.0  ...    1791000.0    1807106.0    1818117.0
# 262    5641598.0    5727745.0  ...   23807586.0   24473176.0   25147112.0
# 263   18896303.0   19384838.0  ...   52003759.0   52832659.0   53687125.0
# 264    3463211.0    3570466.0  ...   14023199.0   14465148.0   14926551.0
# 265    4322854.0    4471178.0  ...   12894323.0   13115149.0   13350378.0
#
#             2014         2015         2016         2017         2018  \
# 0       103776.0     104339.0     104865.0     105361.0     105846.0
# 1    578075373.0  593871847.0  609978946.0  626392880.0  643090131.0
# 2     33370804.0   34413603.0   35383028.0   36296111.0   37171922.0
# 3    390882979.0  401586651.0  412551299.0  423769930.0  435229381.0
# 4     26941773.0   27884380.0   28842482.0   29816769.0   30809787.0
# ..           ...          ...          ...          ...          ...
# 261    1812771.0    1788196.0    1777557.0    1791003.0    1797085.0
# 262   25823488.0   26497881.0   27168210.0   27834811.0   28498683.0
# 263   54544184.0   55386369.0   56207649.0   57009751.0   57792520.0
# 264   15399793.0   15879370.0   16363449.0   16853608.0   17351714.0
# 265   13586710.0   13814642.0   14030338.0   14236599.0   14438812.0
#
#             2019         2020
# 0       106310.0     106766.0
# 1    660046272.0  677243299.0
# 2     38041757.0   38928341.0
# 3    446911598.0  458803476.0
# 4     31825299.0   32866268.0
# ..           ...          ...
# 261    1788878.0    1775378.0
# 262   29161922.0   29825968.0
# 263   58558267.0   59308690.0
# 264   17861034.0   18383956.0
# 265   14645473.0   14862927.0
#
# [266 rows x 65 columns]

# %%
dataset['World Population']
# Out:
# 0          54208.0
# 1      130836765.0
# 2        8996967.0
# 3       96396419.0
# 4        5454938.0
#           ...
# 261       947000.0
# 262      5315351.0
# 263     17099836.0
# 264      3070780.0
# 265      3776679.0
# Name: World Population, Length: 266, dtype: float64

# %%
dataset.drop(['Indicator Name'],axis=1)
# Out:
#                     Country Name Country Code Indicator Code  \
# 0                          Aruba          ABW    SP.POP.TOTL
# 1    Africa Eastern and Southern          AFE    SP.POP.TOTL
# 2                    Afghanistan          AFG    SP.POP.TOTL
# 3     Africa Western and Central          AFW    SP.POP.TOTL
# 4                         Angola          AGO    SP.POP.TOTL
# ..                           ...          ...            ...
# 261                       Kosovo          XKX    SP.POP.TOTL
# 262                  Yemen, Rep.          YEM    SP.POP.TOTL
# 263                 South Africa          ZAF    SP.POP.TOTL
# 264                       Zambia          ZMB    SP.POP.TOTL
# 265                     Zimbabwe          ZWE    SP.POP.TOTL
#
#      World Population         1961         1962         1963         1964  \
# 0             54208.0      55434.0      56234.0      56699.0      57029.0
# 1         130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2           8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3          96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4           5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
# ..                ...          ...          ...          ...          ...
# 261          947000.0     966000.0     994000.0    1022000.0    1050000.0
# 262         5315351.0    5393034.0    5473671.0    5556767.0    5641598.0
# 263        17099836.0   17524533.0   17965733.0   18423157.0   18896303.0
# 264         3070780.0    3164330.0    3260645.0    3360099.0    3463211.0
# 265         3776679.0    3905038.0    4039209.0    4178726.0    4322854.0
#
#             1965         1966  ...         2011         2012         2013  \
# 0        57357.0      57702.0  ...     102050.0     102565.0     103165.0
# 1    148769974.0  152752671.0  ...  532760424.0  547482863.0  562601578.0
# 2      9956318.0   10174840.0  ...   30117411.0   31161378.0   32269592.0
# 3    107289875.0  109701811.0  ...  360285439.0  370243017.0  380437896.0
# 4      5770573.0    5781305.0  ...   24220660.0   25107925.0   26015786.0
# ..           ...          ...  ...          ...          ...          ...
# 261    1078000.0    1106000.0  ...    1791000.0    1807106.0    1818117.0
# 262    5727745.0    5816241.0  ...   23807586.0   24473176.0   25147112.0
# 263   19384838.0   19888259.0  ...   52003759.0   52832659.0   53687125.0
# 264    3570466.0    3681953.0  ...   14023199.0   14465148.0   14926551.0
# 265    4471178.0    4623340.0  ...   12894323.0   13115149.0   13350378.0
#
#             2014         2015         2016         2017         2018  \
# 0       103776.0     104339.0     104865.0     105361.0     105846.0
# 1    578075373.0  593871847.0  609978946.0  626392880.0  643090131.0
# 2     33370804.0   34413603.0   35383028.0   36296111.0   37171922.0
# 3    390882979.0  401586651.0  412551299.0  423769930.0  435229381.0
# 4     26941773.0   27884380.0   28842482.0   29816769.0   30809787.0
# ..           ...          ...          ...          ...          ...
# 261    1812771.0    1788196.0    1777557.0    1791003.0    1797085.0
# 262   25823488.0   26497881.0   27168210.0   27834811.0   28498683.0
# 263   54544184.0   55386369.0   56207649.0   57009751.0   57792520.0
# 264   15399793.0   15879370.0   16363449.0   16853608.0   17351714.0
# 265   13586710.0   13814642.0   14030338.0   14236599.0   14438812.0
#
#             2019         2020
# 0       106310.0     106766.0
# 1    660046272.0  677243299.0
# 2     38041757.0   38928341.0
# 3    446911598.0  458803476.0
# 4     31825299.0   32866268.0
# ..           ...          ...
# 261    1788878.0    1775378.0
# 262   29161922.0   29825968.0
# 263   58558267.0   59308690.0
# 264   17861034.0   18383956.0
# 265   14645473.0   14862927.0
#
# [266 rows x 64 columns]

# %% [markdown]
# ### Step 2.e: Visualize data
# - This is done to check data quality
# - You can plot the DataFrame with `.plot()`

# %% [markdown]
# ## Step 3: Analyze
# - Feature selection
# - Model selection
# - Analyze data

# %% [markdown]
# ### Step 3.a: Calculate yearly percentage change
# - We want to explore the growth of the world population
# - First step is to calculate the yearly growth
# - This can be done with `pct_change()` ([docs](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pct_change.html))
# - Add a new column `Yearly growth` with the growth in percentage

# %% [markdown]
# ### Step 3.b: Visualize the Yearly growth
# - Plot it with `.plot()`
# - This will give you an idea of the trend.

# %% [markdown]
# ### Step 3.c: Smooth the result
# - A great way is to smooth the result
# - This can show local tendencies
# - Calculate a 10-years rolling average by using [rolling(10)](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rolling.html).[mean()](https://pandas.pydata.org/docs/reference/api/pandas.core.window.rolling.Rolling.mean.html)
# ```Python
# dataset['Yearly growth'].rolling(10).mean()
# ```
# - Visualize the result
#     - HINT: Make a plot containing `Yearly growth` and the new calculation.
# - What does that tell you?

# %%
df=dataset['1990'].rolling(10).mean()
df
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#           ...
# 261    539057792.9
# 262    538177791.6
# 263    541847093.4
# 264    540687511.8
# 265    541729003.8
# Name: 1990, Length: 266, dtype: float64

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Step 4: Report
# - Present findings
# - Visualize results
# - Credibility counts

# %% [markdown]
# ### Step 4.a: Transform data
# - To make plot more readable transform data to percentage
#     - HINT: Multiply columns data `Yearly growth` and the smoothed data by 100

# %% [markdown]
# ### Step 4.b: Set title and labels on axis
# - In the plot set labels and axis
#     - `xlabel='Year'` the same for `ylabel` and `title`

# %% [markdown]
# ### Step 4.c: Adding ranges on axis
# - Add range on y-axis to make the plot more readable.
# - Use `ylim=0`

# %% [markdown]
# ## Step 5: Actions
# - Use insights
# - Measure impact
# - Main goal

# %% [markdown]
# ### Step 5.a
# - Any insights to use?
# - Do we need to make predictions based on it?
